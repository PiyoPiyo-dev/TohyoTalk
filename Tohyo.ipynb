# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyoPiyo-dev/TohyoTalk/blob/main/Tohyo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 最初に実行
# !pip install requests_toolbelt
import requests
import json
import time
import datetime
import random
import string
from requests_toolbelt import MultipartEncoder
from PIL import Image
from io import BytesIO


class TohyoTalk:
    def __init__(self, debug=False):
        self.headers = {
            'authority': 'tohyotalk.com',
            'accept': 'application/json, text/javascript, */*; q=0.01',
            'accept-language': 'ja',
            'content-keep': 'on',
            'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
            'origin': 'https://tohyotalk.com',
            'referer': 'https://tohyotalk.com',
            'sec-fetch-dest': 'empty',
            'sec-fetch-mode': 'cors',
            'sec-fetch-site': 'same-origin',
            'user-agent': 'Mozilla/5.0 (iPad; CPU OS 13_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) CriOS/87.0.4280.77 Mobile/15E148 Safari/604.1 Edg/112.0.0.0',
            'x-requested-with': 'XMLHttpRequest',
        }
        self.debug = debug
        self.data = None

    def get_fueldid(self, proxy=None):
        proxies = {
            "http": proxy,
            "https": proxy,
        }
        r = requests.get('https://tohyotalk.com/', proxies=proxies)
        return r.cookies.get('fueldid')

    def create_account(self, userId, userName, password="password", proxy=None):
        self.fueldid = self.get_fueldid(proxy)
        proxies = {
            "http": proxy,
            "https": proxy,
        }
        cookies = {
            'sf': '4',
            'fueldid': self.fueldid
        }
        data = {
            'tt_id': userId,
            'tt_name': userName,
            'mode': 'set_id_name'
        }

        r = requests.post('https://tohyotalk.com/api/updateaccount.json',
                          cookies=cookies, headers=self.headers, data=data, proxies=proxies)
        if self.debug:
            print(r.text)
        if json.loads(r.text)["status"] == 0:
            user_id = r.cookies.get("user_id")
            phpsessid = r.cookies.get("PHPSESSID")
            d4 = r.cookies.get("d4")
            cookies = {
                'sf': '4',
                'PHPSESSID': phpsessid,
                'user_id': user_id,
                'd4': d4,
                'fueldid': self.fueldid}
            data = {
                'tt_id': userId,
                'tt_pw': password,
            }
            r = requests.post('https://tohyotalk.com/api/updatepassword.json',
                              cookies=cookies, headers=self.headers, data=data, proxies=proxies)
            self.data = {
                "PHPSESSID": phpsessid,
                "d4": d4,
                "user_id": user_id,
                "userId": userId,
                "password": password
            }
            if self.debug:
                print({
                    "status": True,
                    "userName": userName,
                    "userId": userId,
                    "password": password
                })
            return {
                "status": True,
                "userName": userName,
                "userId": userId,
                "password": password
            }

        else:
            if self.debug:
                print({
                    "status": False,
                })
            return {
                "status": False
            }

    def login(self, userId, password, proxy=None):
        self.fueldid = self.get_fueldid(proxy)
        proxies = {
            "http": proxy,
            "https": proxy,
        }
        cookies = {
            'sf': '4',
            'fueldid': self.fueldid
        }
        data = {
            'tt_id': userId,
            'tt_pw': password,
        }
        r = requests.post('https://tohyotalk.com/api/idrenkei.json',
                          cookies=cookies, headers=self.headers, data=data, proxies=proxies)
        if self.debug:
            print(r.text)
        if json.loads(r.text)["status"] == 0:
            self.data = {
                "PHPSESSID": r.cookies.get("PHPSESSID"),
                "d4": r.cookies.get("d4"),
                "user_id": r.cookies.get("user_id"),
                "userId": userId,
                "password": password
            }
            if self.debug:
                print({
                    "status": True,
                })
            return {
                "status": True,
            }
        else:
            if self.debug:
                print({
                    "status": False,
                })
            return {
                "status": False,
            }

    def vote(self, vote_id, target, proxy=None):
        if not self.data == None:
            fueldid = self.fueldid
            proxies = {
                "http": proxy,
                "https": proxy,
            }
            cookies = {
                'sf': '4',
                'PHPSESSID': self.data["PHPSESSID"],
                'user_id': self.data["user_id"],
                'd4': self.data["d4"],
                'fueldid': fueldid
            }
            data = {
                'id': vote_id,
                'target': target,
            }
            r = requests.post('https://tohyotalk.com/api/vote.json',
                              cookies=cookies, headers=self.headers, data=data, proxies=proxies)
            if self.debug:
                print(r.text)
            if json.loads(r.text)["status"] == 0:
                if self.debug:
                    print({
                        "status": True
                    })
                return {
                    "status": True
                }
            else:
                if self.debug:
                    print({
                        "status": False
                    })
                return {
                    "status": False
                }
        else:
            if self.debug:
                print({
                    "status": False
                })
            return {
                "status": False
            }

    def tweet(self, content, proxy=None):
        if not self.data == None:
            fueldid = self.fueldid
            proxies = {
                "http": proxy,
                "https": proxy,
            }
            cookies = {
                'sf': '4',
                'PHPSESSID': self.data["PHPSESSID"],
                'user_id': self.data["user_id"],
                'd4': self.data["d4"],
                'fueldid': fueldid
            }
            data = {
                'question_id': '-380',
                'content': content,
            }
            r = requests.post('https://tohyotalk.com/api/createmsg2.json',
                              cookies=cookies, headers=self.headers, data=data, proxies=proxies)
            if self.debug:
                print(r.text)
            if json.loads(r.text)["status"] == 0:
                if self.debug:
                    print({
                        "status": True,
                        "msgId": json.loads(r.text)["msgId"]
                    })
                return {
                    "status": True,
                    "msgId": json.loads(r.text)["msgId"]
                }
            else:
                if self.debug:
                    print({
                        "status": False
                    })
                return {
                    "status": False
                }
        else:
            if self.debug:
                print({
                    "status": False
                })
            return {
                "status": False
            }

    def follow(self, id, proxy=None):
        if not self.data == None:
            fueldid = self.fueldid
            proxies = {
                "http": proxy,
                "https": proxy,
            }
            cookies = {
                'sf': '4',
                'PHPSESSID': self.data["PHPSESSID"],
                'user_id': self.data["user_id"],
                'd4': self.data["d4"],
                'fueldid': fueldid
            }
            data = {
                'tt_id': id,
                'followed': "",
            }
            r = requests.post('https://tohyotalk.com/api/saveuserfollowuser.json',
                              cookies=cookies, headers=self.headers, data=data, proxies=proxies)
            if self.debug:
                print(r.text)
            if json.loads(r.text)["status"] == 0:
                if self.debug:
                    print({
                        "status": True
                    })
                return {
                    "status": True
                }
            else:
                if self.debug:
                    print({
                        "status": False
                    })
                return {
                    "status": False
                }
        else:
            if self.debug:
                print({
                    "status": False
                })
            return {
                "status": False
            }

    def like(self, msgId, proxy=None):
        if not self.data == None:
            fueldid = self.get_fueldid(proxy)
            proxies = {
                "http": proxy,
                "https": proxy,
            }
            cookies = {
                'sf': '4',
                'PHPSESSID': self.data["PHPSESSID"],
                'user_id': self.data["user_id"],
                'd4': self.data["d4"],
                'fueldid': fueldid
            }
            data = {
                'msg_id': msgId,
                'eval_mode': 'plus',
            }
            r = requests.post('https://tohyotalk.com/api/evalmsg.json',
                              cookies=cookies, headers=self.headers, data=data, proxies=proxies)
            if self.debug:
                print(r.text)
            if json.loads(r.text)["status"] == 0:
                if self.debug:
                    print({
                        "status": True
                    })
                return {
                    "status": True
                }
            else:
                if self.debug:
                    print({
                        "status": False
                    })
                return {
                    "status": False
                }
        else:
            if self.debug:
                print({
                    "status": False
                })
            return {
                "status": False
            }

    def game(self, score, proxy=None):
        if not self.data == None:
            fueldid = self.fueldid
            proxies = {
                "http": proxy,
                "https": proxy,
            }
            cookies = {
                'sf': '4',
                'PHPSESSID': self.data["PHPSESSID"],
                'user_id': self.data["user_id"],
                'd4': self.data["d4"],
                'fueldid': fueldid
            }
            data = {
                'game_id': '1',
                'game_version': '1',
                'score': score,
                'play_id': '',
            }
            r = requests.post('https://tohyotalk.com/api/saveusergamescore.json',
                              cookies=cookies, headers=self.headers, data=data, proxies=proxies)
            if self.debug:
                print(r.text)
            if json.loads(r.text)["status"] == 0:
                if self.debug:
                    print({
                        "status": True,
                        "rank": json.loads(r.text)["this_rank"]
                    })
                return {
                    "status": True,
                    "rank": json.loads(r.text)["this_rank"]
                }
            else:
                if self.debug:
                    print({
                        "status": False
                    })
                return {
                    "status": False
                }
        else:
            if self.debug:
                print({
                    "status": False
                })
            return {
                "status": False
            }

    def icon(self, icon_path, proxy=None):
        if not self.data == None:
            fueldid = self.fueldid
            proxies = {
                "http": proxy,
                "https": proxy,
            }
            cookies = {
                'sf': '4',
                'PHPSESSID': self.data["PHPSESSID"],
                'user_id': self.data["user_id"],
                'd4': self.data["d4"],
                'fueldid': fueldid
            }
            fields = {
                'file': (icon_path, open(icon_path, 'rb'), "image/png"),
                'file_id': "0"
            }
            boundary = '----WebKitFormBoundary' \
                + ''.join(random.sample(string.ascii_letters + string.digits, 16))
            data = MultipartEncoder(
                fields=fields, boundary=boundary)
            headers = {
                'authority': 'tohyotalk.com',
                'accept': 'application/json, text/javascript, */*; q=0.01',
                'accept-language': 'ja',
                'content-keep': 'on',
                'content-type': data.content_type,
                'origin': 'https://tohyotalk.com',
                'referer': 'https://tohyotalk.com/account/id',
                'sec-fetch-dest': 'empty',
                'sec-fetch-mode': 'cors',
                'sec-fetch-site': 'same-origin',
                'user-agent': 'Mozilla/5.0 (iPad; CPU OS 13_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) CriOS/87.0.4280.77 Mobile/15E148 Safari/604.1 Edg/112.0.0.0',
                'x-requested-with': 'XMLHttpRequest',
            }
            r = requests.post('https://tohyotalk.com/api/uploadimg.json',
                              cookies=cookies, headers=headers, data=data, proxies=proxies
                              )
            if json.loads(r.text)["status"] == 0:
                x, y = Image.open(BytesIO(requests.get(
                    json.loads(r.text)["uploaded_file_url"]).content)).size
                data = {
                    'uploaded_file_name': json.loads(r.text)["uploaded_file_name"],
                    'zoom': '0.1667',
                    'x1': '0',
                    'y1': '0',
                    'x2': x,
                    'y2': y,
                }
                r = requests.post('https://tohyotalk.com/api/cropimg.json',
                                  cookies=cookies, headers=self.headers, data=data, proxies=proxies)
                if json.loads(r.text)["status"] == 0:
                    if self.debug:
                        print({
                            "status": True
                        })
                    return {
                        "status": True
                    }
                else:
                    if self.debug:
                        print({
                            "status": False
                        })
                    return {
                        "status": False
                    }
            else:
                if self.debug:
                    print({
                        "status": False
                    })
                return {
                    "status": False
                }
        else:
            if self.debug:
                print({
                    "status": False
                })
            return {
                "status": False
            }

    def profile(self, content, proxy=None):
        if not self.data == None:
            fueldid = self.fueldid
            proxies = {
                "http": proxy,
                "https": proxy,
            }
            cookies = {
                'sf': '4',
                'PHPSESSID': self.data["PHPSESSID"],
                'user_id': self.data["user_id"],
                'd4': self.data["d4"],
                'fueldid': fueldid
            }
            data = {
                'tt_id': self.data["userId"],
                'content': content
            }
            r = requests.post('https://tohyotalk.com/api/saveprofilecontent.json',
                              cookies=cookies, headers=self.headers, data=data, proxies=proxies)
            if self.debug:
                print(r.text)
            if json.loads(r.text)["status"] == 0:
                if self.debug:
                    print({
                        "status": True
                    })
                return {
                    "status": True
                }
            else:
                if self.debug:
                    print({
                        "status": False
                    })
                return {
                    "status": False
                }
        else:
            if self.debug:
                print({
                    "status": False
                })
            return {
                "status": False
            }

# %%
account_list = "inthetown_6400,inthetown_6171,inthetown_4552,inthetown_9753,inthetown_5204,inthetown_7715,inthetown_4156,inthetown_8237,inthetown_3418,inthetown_1409,inthetown_16510,inthetown_91611,inthetown_56212,inthetown_95613,inthetown_18914,inthetown_16515,inthetown_69316,inthetown_58317,inthetown_61618,inthetown_10819,inthetown_94020,inthetown_33321,inthetown_46422,inthetown_41023,inthetown_44924,inthetown_12125,inthetown_64826,inthetown_92227,inthetown_21528,inthetown_91429,inthetown_21430,inthetown_40931,inthetown_62032,inthetown_94433,inthetown_60434,inthetown_34235,inthetown_92336,inthetown_27037,inthetown_10738,inthetown_47539,inthetown_76640,inthetown_94741,inthetown_82742,inthetown_19343,inthetown_61944,inthetown_73845,inthetown_23446,inthetown_68247,inthetown_12148,inthetown_28149,inthetown_96750,inthetown_92751,inthetown_44552,inthetown_67153,inthetown_23254,inthetown_76155,inthetown_22856,inthetown_47457,inthetown_95058,inthetown_57459,inthetown_15360,inthetown_17861,inthetown_56862,inthetown_28263,inthetown_25664,inthetown_89265,inthetown_55466,inthetown_95767,inthetown_28068,inthetown_80669,inthetown_50070,inthetown_40971,inthetown_10772,inthetown_29873,inthetown_30474,inthetown_91375,inthetown_22376,inthetown_99177,inthetown_11978,inthetown_30879,inthetown_64080,inthetown_97081,inthetown_58082,inthetown_28983,inthetown_12684,inthetown_47485,inthetown_54086,inthetown_15787,inthetown_73488,inthetown_53589,inthetown_57390,inthetown_55191,inthetown_13392,inthetown_18293,inthetown_97594,inthetown_10995,inthetown_73296,inthetown_71297,inthetown_87598,inthetown_29799".split(",")

# %%
Tohyo = TohyoTalk(debug=False)
for userID in account_list:
  time.sleep(1)
  Tohyo.login(userID, "password")
  dt_now = datetime.datetime.now(datetime.timezone(datetime.timedelta(hours=9)))
  Tohyo.tweet(dt_now.strftime('現在時刻は%H時%M分%S秒です'))

# %%
Tohyo = TohyoTalk(debug=False)
for userID in account_list:
  time.sleep(1)
  Tohyo.login(userID, "password")
  Tohyo.game(21)

# %%
Tohyo = TohyoTalk(debug=False)
for i in range(100):
  time.sleep(2)
  Tohyo.create_account("野獣先輩_", "password")
  dt_now = datetime.datetime.now(datetime.timezone(datetime.timedelta(hours=9)))
  Tohyo.tweet(dt_now.strftime('現在時刻は%H時%M分%S秒です'))
  Tohyo.game(23)

# %%
Tohyo = TohyoTalk(debug=False)
aclist = []
for i in range(100):
    time.sleep(1)
    r = Tohyo.create_account(
        f"iiyokoiyo{random.randint(100, 999)}{i}", f"野獣先輩{random.randint(100, 999)}{i}")
    if r["status"]:
        aclist.append(r["userId"])
        print(r["userId"])
        time.sleep(1)
        Tohyo.icon("icon.png")
        time.sleep(1)
        dt = datetime.datetime.now(datetime.timezone(datetime.timedelta(hours=9)))
        Tohyo.tweet(dt.strftime('現在時刻は%H時%M分%S秒です'))
        Tohyo.game(23)
with open("account.txt", "w") as f:
    f.write(",".join(aclist))
# Out:
# iiyokoiyo4000
# iiyokoiyo5771
# iiyokoiyo3752
# iiyokoiyo3353
# iiyokoiyo7674
# iiyokoiyo9825
# iiyokoiyo2226
# iiyokoiyo2937
# iiyokoiyo9428
# iiyokoiyo8419
# iiyokoiyo98210
# iiyokoiyo54411
# iiyokoiyo61312
# iiyokoiyo31413
# iiyokoiyo51714
# iiyokoiyo13715
# iiyokoiyo47416
# iiyokoiyo62317
# iiyokoiyo78018
# iiyokoiyo19719
# iiyokoiyo11920
# iiyokoiyo83821
# iiyokoiyo97122
# iiyokoiyo25623
# iiyokoiyo64524
# iiyokoiyo97125
# iiyokoiyo66626
# iiyokoiyo95827
# iiyokoiyo57928
# iiyokoiyo56429
# iiyokoiyo63230
# iiyokoiyo89231
# iiyokoiyo80432
# iiyokoiyo38033
# iiyokoiyo49834
# iiyokoiyo88335
# iiyokoiyo60536
# iiyokoiyo41737
# iiyokoiyo31138
# iiyokoiyo61239
# iiyokoiyo89940
# iiyokoiyo18541
# iiyokoiyo62842
# iiyokoiyo59643
# iiyokoiyo43744
# iiyokoiyo14645
# iiyokoiyo89346
# iiyokoiyo35347
# iiyokoiyo62048
# iiyokoiyo79949
# iiyokoiyo81350
# iiyokoiyo93651
# iiyokoiyo56652
# iiyokoiyo58053
# iiyokoiyo84454
# iiyokoiyo23555
# iiyokoiyo11756
# iiyokoiyo49757
# iiyokoiyo55358
# iiyokoiyo75659
# iiyokoiyo35060
# iiyokoiyo52261
# iiyokoiyo83562
# iiyokoiyo52363
# iiyokoiyo89164
# iiyokoiyo23665
# iiyokoiyo57766
# iiyokoiyo10267
# iiyokoiyo84568
# iiyokoiyo62569
# iiyokoiyo59570
# iiyokoiyo30871
# iiyokoiyo40472
# iiyokoiyo97073
# iiyokoiyo59274
# iiyokoiyo58075
# iiyokoiyo35376
# iiyokoiyo71877
# iiyokoiyo94578
# iiyokoiyo40379
# iiyokoiyo48980
# iiyokoiyo24181
# iiyokoiyo12482
# iiyokoiyo76583
# iiyokoiyo88084
# iiyokoiyo35285
# iiyokoiyo77286
# iiyokoiyo98287
# iiyokoiyo78488
# iiyokoiyo25089
# iiyokoiyo90690
# iiyokoiyo25091
# iiyokoiyo74192
# iiyokoiyo97193
# iiyokoiyo93594
# iiyokoiyo18895
# iiyokoiyo33696
# iiyokoiyo65797
# iiyokoiyo59198
# iiyokoiyo52299
